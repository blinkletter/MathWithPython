# %% [markdown]
# #### Python and Chemistry: The Notebooks

# %% [markdown]
# # Python and Chemistry
# Welcome to a series of interactive python notebooks that introduce a few basic skills in scientific computing. By exploring the first five notebooks you will gain skills in using python as a calculator and in interpretting data with line fits and plots. The remaining notebooks present additional information that you may find useful. Python can be your everything. Embrace python and python will embrace you.
# ## Basic Skills
# The following two notebooks present the basics of using python as a calculator and making plots of a function. After working through them and changing thibgs to see what happens, you will be able to use a python notebook as a graphing calculator.
# #### Basics, Part 1
# >**Title**: Basic Math with Python      <br>
# >**Filename**: [1-1-Calculator.ipynb](1-1-Calculator.ipynb)   <br>
# >**Tools**: NumPy       <br>
# >**Skills**: Basic math operations, using the tools of NumPy
#
# #### Basics, Part 2
# >**Title**: Making Plots Using Python      <br>
# >**Filename**: [1-2-Simple_Plots.ipynb](1-2-Simple_Plots.ipynb)   <br>
# >**Tools**: NumPy, MatPlotLib      <br>
# >**Skills**: Basic plotting of functions
#
# # Interpretting Data
# The three notebopoks below explore plotting experimental data and fitting that data to a model (curve fitting) to obtain experimental parameters. You will also learn some basics about styling the plots and formatting results for text output.
# #### Plotting Data, Part 1
# >**Title**: Making Better Plots      <br>
# >**Filename**: [2-1-Better_Plots.ipynb](2-1-Better_Plots.ipynb)    <br>
# >**Tools**: NumPy, MatPlotLib      <br>
# >**Skills**: Basic plot styling, adding labels and titles, styling the line
#
# #### Plotting Data, Part 2
# >**Title**: Introduction to Pandas and Plotting Data      <br>
# >**Filename**: [2-2-Plotting_Data.ipynb](2-2-Plotting_Data.ipynb)    <br>
# >**Tools**: NumPy, Pandas, MatPlotLib      <br>
# >**Skills**: The Pandas dataframe, plotting data, inputting data, reading data from a file, styling plot markers
#
# #### Plotting Data, Part 3
# >**Title**: Introduction to SciPy and Fitting Data      <br>
# >**Filename**: [2-3-Fitting.ipynb](2-3-Fitting.ipynb)   <br>
# >**Tools**: NumPy, Pandas, MatPlotLib, SciPy      <br>
# >**Skills**: Optimized curve fits, linear regression, basic statistical information, using the `str.format()` method
#
#
# ## More Skills
# The notebooks below explore additional skill such as more advanced styling of plots and using python for solving equations.
# #### Skills, Part 1
# >**Title**: Using Python Instead of Microsoft Excel      <br>
# >**Filename**: [S1-Python_Instead_of_Excel.ipynb](S1-Python_Instead_of_Excel.ipynb)   <br>
# >**Tools**: NumPy, Pandas, MatPlotLib, SciPy      <br>
# >**Skills**: Plotting data, inputting data, reading data from a file, linear regression, basic statistics. using the `n.round()` method for NumPy floats.
#
# #### Skills, Part 2
# >**Title**: Styling Plots      <br>
# >**Filename**: [S2-Styling_Plots.ipynb](S2-Styling_Plots.ipynb)   <br>
# >**Tools**: NumPy, Pandas, MatPlotLib, SciPy       <br>
# >**Skills**: Setting style parameters for plots, using stylesheets, examples of plot styling
# #### Skills, Part 3
# >**Title**: Solving Equations with SymPy <br>
# >**Filename**: [S3-Solving_Equations.ipynb](S3-Solving_Equations.ipynb) <br>
# >**Tools**: SymPy <br>
# >**Skills**: Solving symbolic math equations using SymPy, plotting symbolic functions using SymPy
#
#
# ## Exercises
# These notebooks explore applications to chemistry problems. In each a goal is set and solved by using the tools available to python. Along the way new skills will be gained.
#
# #### Exercise 1
# >**Title**: The ICE Table in Python    <br>
# >**Filename**: [E1-The_ICE_Table_in_Python.ipynb](E1-The_ICE_Table_in_Python.ipynb)   <br>
# >**Tools**: SymPy      <br>
# >**Skills**: Solving an equilibrium reaction via the ICE method, symbolic math, using the `str.format()` method
#
# #### Exercise 2
# >**Title**: Plotting in Reaction Kinetics to Determine Order    <br>
# >**Filename**: [E2-Plotting_Reaction_Kinetics_to_Determine_Order.ipynb](E2-Plotting_Reaction_Kinetics_to_Determine_Order.ipynb)   <br>
# >**Tools**: NumPy, Pandas, MatPlotLib, SciPy      <br>
# >**Skills**: reading data from a file, the Pandas dataframe, basic plotting, linear regression
#
# #### Exercise 3
# >**Title**: Order of Reaction via Python    <br>
# >**Filename**: [E3-Order_of_Reaction_via_Python.ipynb](E3-Order_of_Reaction_via_Python.ipynb)   <br>
# >**Tools**: NumPy, Pandas, MatPlotLib, SciPy      <br>
# >**Skills**: The Pandas dataframe, converting data to a dataframe, basic plotting, linear regression, NumPy log function
